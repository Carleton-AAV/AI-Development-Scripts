# %%
pip install ultralytics
pip install cv2
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.57-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.8/486.8 kB 6.8 MB/s eta 0:00:00a 0:00:01
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.7.1-cp311-cp311-macosx_11_0_arm64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 64.0 MB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.21.6
#   Downloading numpy-1.24.2-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.0 MB/s eta 0:00:0000:0100:01
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.7.0.72-cp37-abi3-macosx_11_0_arm64.whl (32.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/32.6 MB 21.8 MB/s eta 0:00:0000:0100:01
# Collecting Pillow>=7.1.2
#   Downloading Pillow-9.4.0-cp311-cp311-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 52.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from ultralytics) (6.0)
# Collecting requests>=2.23.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 10.7 MB/s eta 0:00:00
# Collecting scipy>=1.4.1
#   Downloading scipy-1.10.1-cp311-cp311-macosx_12_0_arm64.whl (28.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.7/28.7 MB 53.1 MB/s eta 0:00:0000:0100:01
# Collecting torch>=1.7.0
#   Downloading torch-2.0.0-cp311-none-macosx_11_0_arm64.whl (55.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 29.6 MB/s eta 0:00:0000:0100:01
# Collecting torchvision>=0.8.1
#   Downloading torchvision-0.15.1-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 45.2 MB/s eta 0:00:00
# Collecting tqdm>=4.64.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 11.4 MB/s eta 0:00:00
# Collecting pandas>=1.1.4
#   Downloading pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 48.2 MB/s eta 0:00:0000:010:01
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from ultralytics) (5.9.4)
# Collecting thop>=0.1.1
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.17.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 kB 17.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 21.9 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.2-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/sip/6.7.5/libexec/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/sip/6.7.5/libexec/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 34.8 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.7/121.7 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 22.3 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 17.9 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.10.4-py3-none-any.whl (10 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 41.7 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: six>=1.5 in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tshih/Library/Python/3.11/lib/python/site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.2)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 33.9 MB/s eta 0:00:00
# Installing collected packages: pytz, mpmath, urllib3, typing-extensions, tqdm, sympy, Pillow, numpy, networkx, kiwisolver, fonttools, filelock, cycler, charset-normalizer, certifi, torch, sentry-sdk, scipy, requests, pandas, opencv-python, contourpy, torchvision, thop, matplotlib, seaborn, ultralytics
# Successfully installed Pillow-9.4.0 certifi-2022.12.7 charset-normalizer-3.1.0 contourpy-1.0.7 cycler-0.11.0 filelock-3.10.4 fonttools-4.39.2 kiwisolver-1.4.4 matplotlib-3.7.1 mpmath-1.3.0 networkx-3.0 numpy-1.24.2 opencv-python-4.7.0.72 pandas-1.5.3 pytz-2022.7.1 requests-2.28.2 scipy-1.10.1 seaborn-0.12.2 sentry-sdk-1.17.0 sympy-1.11.1 thop-0.1.1.post2209072238 torch-2.0.0 torchvision-0.15.1 tqdm-4.65.0 typing-extensions-4.5.0 ultralytics-8.0.57 urllib3-1.26.15
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
The Function below oracestrates the entire operation and performs the real-time parsing for video stream.
"""
def __call__(self):
    player = self.get_video_stream() #Get your video stream.
    assert player.isOpened() # Make sure that their is a stream. 
    #Below code creates a new video writer object to write our
    #output stream.
    x_shape = int(player.get(cv2.CAP_PROP_FRAME_WIDTH))
    y_shape = int(player.get(cv2.CAP_PROP_FRAME_HEIGHT))
    four_cc = cv2.VideoWriter_fourcc(*"MJPG") #Using MJPEG codex
    out = cv2.VideoWriter(out_file, four_cc, 20, \
                          (x_shape, y_shape)) 
    ret, frame = player.read() # Read the first frame.
    while rect: # Run until stream is out of frames
        start_time = time() # We would like to measure the FPS.
        results = self.score_frame(frame) # Score the Frame
        frame = self.plot_boxes(results, frame) # Plot the boxes.
        end_time = time()
        fps = 1/np.round(end_time - start_time, 3) #Measure the FPS.
        print(f"Frames Per Second : {fps}")
        out.write(frame) # Write the frame onto the output.
        ret, frame = player.read() # Read next frame.
